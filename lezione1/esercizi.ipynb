# %%
# Carica la API key dai Colab Secrets
import anthropic
import os
from dotenv import load_dotenv

# Load variables from .env file into os.environ
load_dotenv()

# Access environment variables
key = os.getenv("ANTHROPIC_API_KEY")

# Crea il client
client = anthropic.Anthropic()

if key.startswith("sk-ant"):
    print(f"✅ API key configurata correttamente: sk-ant-...{key[-6:]}")
else:
    print("❌ API key non trovata. Controlla i Colab Secrets.")
# Out:
# ✅ API key configurata correttamente: sk-ant-...XtSAAA

# %%
# Funzione helper — la useremo in tutti gli esercizi
def chiedi_claude(domanda, temperature=0.7, system=None, max_tokens=300):
    """Invia una domanda a Claude e restituisce la risposta testuale."""
    params = {
        "model": "claude-haiku-4-5-20251001",
        "max_tokens": max_tokens,
        "temperature": temperature,
        "messages": [{"role": "user", "content": domanda}]
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

print("✅ Funzione helper pronta!")
# Out:
# ✅ Funzione helper pronta!

# %% [markdown]
# ---
# ## ⭐ Esercizi
#
# > **Completa tutti e 4 gli esercizi, poi scarica il notebook e caricalo su GitHub.**
#
# Scrivi il tuo nome qui sotto prima di iniziare:

# %%
NOME_STUDENTE = "Alfonso Mammato"  # ← SCRIVI IL TUO NOME QUI

if NOME_STUDENTE:
    print(f"✅ Notebook di: {NOME_STUDENTE}")
else:
    print("⚠️  Scrivi il tuo nome nella variabile NOME_STUDENTE!")
# Out:
# ✅ Notebook di: Alfonso Mammato

# %% [markdown]
# ### Esercizio 1 — Base ★☆☆
# Chiedi a Claude qualcosa che ti interessa davvero — un consiglio, una spiegazione, una curiosità.

# %%
# ESERCIZIO 1 — Sostituisci la domanda con qualcosa di tuo

mia_domanda = "Qual è la città più bella della Sardegn"  # ← SCRIVI LA TUA DOMANDA

# TODO: chiama chiedi_claude() con la tua domanda e stampa la risposta
print(chiedi_claude(mia_domanda))
# Out:
# # Le città più belle della Sardegna
#
# È difficile eleggere una sola vincitrice, ma ecco le principali candidate:
#
# ## **Porto Cervo**
# - Affascinante porto turistico della Costa Smeralda
# - Architettura elegante e yachting di lusso
# - Paesaggio spettacolare
#
# ## **Alghero**
# - Centro storico medievale ben conservato
# - Mura aragonesi e torri costiere
# - Atmosfera autentica e affascinante
#
# ## **Castelsardo**
# - Borgo arroccato sul promontorio
# - Castello medioevale dominante
# - Viste panoramiche straordinarie
#
# ## **Bosa**
# - Coloratissimo con case affacciate sul fiume Temo
# - Architettura variopinta unica
# - Atmosfera romantica e pittoresca
#
# ## **Cagliari**
# - Capitale con il Castello di San Michele
# - Anfiteatro romano e musei importanti
# - Vivacità urbana e storia millenaria
#
# **La scelta dipende dai tuoi gusti**: se preferisci lusso e modernità scegli Porto Cervo, se ami storia e autenticità Alghero o Bosa

# %% [markdown]
# ### Esercizio 2 — Intermedio ★★☆
# Fai la stessa domanda 3 volte con `temperature=0` e 3 volte con `temperature=1`.
# Le risposte sono diverse? Scrivi un commento con quello che hai osservato.

# %%
# ESERCIZIO 2
domanda_test = "Inventa un titolo per un film di fantascienza ambientato in Sardegna."

print("temperature = 0.0 (3 chiamate):")
for i in range(3):
    print(chiedi_claude(domanda_test, temperature=0.0))

print("temperature = 1.0 (3 chiamate):")
for i in range(3):
    print(chiedi_claude(domanda_test, temperature=1))

# TODO: scrivi qui sotto cosa hai osservato (come commento Python)
# Osservazione: ...
# Out:
# temperature = 0.0 (3 chiamate):
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologiche nascoste. Potrebbe essere un film su:
#
# - Astronavi nascoste sotto i nuraghi
# - Una civiltà extraterrestre che ha influenzato la Sardegna antica
# - Un'invasione aliena che risveglia poteri dormienti nelle pietre millenarie
# - Una scoperta scientifica che cambia tutto ciò che sappiamo sulla storia dell'isola
#
# Altre alternative:
# - **"Stella di Barbagia"** (più poetico)
# - **"Il Codice di Tharros"** (archeologico-mistico)
# - **"Oltre l'Arcipelago"** (più epico)
#
# Quale genere preferisci? Potrei suggerire titoli più specifici! 🚀
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologie perdute. Potrebbe essere un film su esploratori che scoprono che la Sardegna nasconde segreti cosmici nei suoi monumenti preistorici.
#
# Altre alternative:
# - **"Isola Temporale"** - un'isola che esiste in più dimensioni
# - **"Il Codice di Tharros"** - una civiltà aliena nascosta nelle rovine antiche
# - **"Oltre il Mare di Smeraldo"** - un viaggio verso un portale interdimensionale
#
# Quale genere di fantascienza ti piacerebbe di più?
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologie perdute. Potrebbe essere un film su esploratori che scoprono che la Sardegna nasconde segreti cosmici nei suoi monumenti preistorici.
#
# Altre alternative:
# - **"Isola Temporale"** - un'isola che esiste in più dimensioni
# - **"Il Codice di Tharros"** - una civiltà antica con tecnologia avanzata
# - **"Oltre il Mare di Barbagia"** - un viaggio nello spazio che inizia dalle coste sarde
# temperature = 1.0 (3 chiamate):
# # "Le Dune Nere di Nuraghe"
#
# Un titolo che mescola elementi caratteristici della Sardegna (i nuraghi, le dune) con un'atmosfera aliena e misteriosa, suggerendo una storia di contatto extraterrestre o scoperta archeologica futuristica nelle terre sarde.
#
# ---
#
# Se preferisci altre opzioni:
# - **"Il Sigillo del Coccovaccio"** (più misterioso)
# - **"Costiera Temporale"** (per una trama sul viaggio nel tempo)
# - **"L'Isola Invisibile"** (per una storia di dimensioni parallele)
# # "Sa Notte de is Stellas"
#
# Un film dove un'astronave aliena si schianta nelle montagne del Gennargentu, e i abitanti di un piccolo paese sardo devono decidere se aiutare gli extraterrestri o consegnarli a un'agenzia governativa misteriosa. Tra tradizioni millenarie, paesaggi selvaggi e tecnologia aliena, scopriranno che la vera minaccia viene da un'altra parte dell'universo.
#
# (Il titolo gioca sulle parole sarde e rimanda alla magia della "notte delle stelle" - perfetto per un'atmosfera di fantascienza affascinante e misteriosa!)
# # "I Sussurri di Nuraghe"
#
# Un titolo che evoca il mistero delle antiche torri nuragiche, immaginandole come strutture aliene lasciate millenni fa sulle coste sarde. Potrebbe essere un film dove archeologhi scoprono che i nuraghi sono in realtà stazioni di osservazione extraterrestre ancora attive, e la Sardegna diventa il palcoscenico di un primo contatto inaspettato.
#
# Alternative che mi vengono in mente:
# - **"Rosso di Marte"** – riferimento al mare e al pianeta rosso
# - **"L'Ultimo Volo da Cagliari"** – più distopico e noir
# - **"Memoria Cosmica"** – giocando con l'idea di una memoria ancestrale sarda
#
# Quale tipo di storia ti affascina di più?

# %% [markdown]
# ### Esercizio 3 — Intermedio ★★☆
# Crea un system prompt che fa rispondere Claude in rima. Poi chiedi qualcosa di banale.

# %%
# ESERCIZIO 3
system_rima = "Rispondi in rima baciata"  # ← SCRIVI UN SYSTEM PROMPT CHE FA RISPONDERE IN RIMA

print(chiedi_claude(domanda="Descrivimi la Sardegna in due strofe", system=system_rima))
# Out:
# # La Sardegna
#
# Quest'isola di sole e di mistero
# Sorge dal mar con spiagge d'oro puro,
# Dove il granito forma un paesaggio severo
# E il vento canta su ogni colle duro.
#
# Le sue genti custodiscono un tesoro
# Di tradizioni antiche e di valori,
# Mentre il tramonto dipinge il mare d'oro
# E la terra profuma di arbusti e fiori.

# %% [markdown]
# ### Esercizio 4 — Avanzato ★★★ (Deliverable!)
# Crea uno script completo che:
# 1. Chiede il nome dell'utente
# 2. Usa il nome nel messaggio a Claude
# 3. Stampa la risposta in modo formattato
#
# > 💡 Su Colab usa `input()` normalmente — comparirà un campo di testo sotto la cella.

# %%
# ESERCIZIO 4 — Chatbot personalizzato (DELIVERABLE)

# 1. Chiedi il nome
nome = input("Come ti chiami? ")

# 2. TODO: crea il messaggio usando il nome
system = f"sei un ingegnere software senior e sarai il mio assistente per i compiti di coding, il mio nome è {nome}"  # ← usa f-string con la variabile nome
messaggio = f"Chiamami per nome, poi spiegami come funziona un array su python"  # ← usa f-string con la variabile nome
TEMPERATURA=0

# 3. TODO: chiama l'API
risposta = chiedi_claude(domanda=messaggio, system=system, temperature=TEMPERATURA)
# 4. TODO: stampa la risposta in modo carino

print(f"Domanda: {messaggio}")
print(   f"Risposta: {risposta}")
# Out:
# Domanda: Chiamami per nome, poi spiegami come funziona un array su python
# Risposta: # Ciao Alfonso! 👋
#
# Sono felice di aiutarti con i tuoi compiti di coding. Parliamo degli **array in Python**.
#
# ## Come funzionano gli array in Python
#
# In Python, la struttura dati più comune per gestire collezioni di elementi è la **lista** (list). Tecnicamente, Python ha anche il modulo `array`, ma le liste sono molto più versatili.
#
# ### Liste - La struttura principale
#
# ```python
# # Creazione di una lista
# numeri = [1, 2, 3, 4, 5]
# nomi = ["Alice", "Bob", "Charlie"]
# mista = [1, "testo", 3.14, True]  # Può contenere tipi diversi
# ```
#
# ### Accesso agli elementi
#
# ```python
# numeri = [10, 20, 30, 40, 50]
#
# # Indexing (gli indici partono da 0)
# print(numeri[0])    # Output: 10
# print(numeri[2])    # Output: 30
# print(numeri[-1])   # Output: 50 (ultimo elemento)
# ```
#
# ### Operazioni comuni
#
# ```python
# lista = [1, 2, 3]
#
# # Aggiungere elementi

# %% [markdown]
# ---
# ## 📤 Consegna
#
# Hai completato tutti e 4 gli esercizi? Perfetto!
#
# ### Come caricare su GitHub:
#
# 1. **Scarica il notebook:**
#    `File → Scarica → Scarica .ipynb`
#
# 2. **Rinomina il file:**
#    `Lezione1_TUONOME.ipynb`
#    Es: `Lezione1_MarioRossi.ipynb`
#
# 3. **Carica su GitHub nel tuo repository personale:**
# ```bash
# # Nella cartella del tuo repo
# cp ~/Downloads/Lezione1_TUONOME.ipynb lezione1/
# git add lezione1/
# git commit -m "Lezione 1 completata"
# git push
# ```
#
# ---
#
# ### 📖 Per la prossima lezione (Giovedì 21/05)
# Leggi **Huyen Cap. 5 — Prompt Engineering** prima di venire in aula.
#
# ---
# *ITS Novitas 4.0 — AI Engineering Fundamentals | Marco Uras*
